# %%
import pandas as pd
from pathlib import Path

# %%
DATA_DIR = Path.cwd().parent / "feature_repo" / "data"
dfc = pd.read_parquet(DATA_DIR / "ames_processed.parquet")
dfc
# Out:
#       Fireplaces  Kitchen.Qual  Remod.Age  Open.Porch.SF  Garage.Age  \
# 0            2.0             2       50.0           62.0        50.0
# 2            0.0             1       52.0           36.0        52.0
# 5            1.0             1       12.0           36.0        12.0
# 15           1.0             0        7.0           36.0         7.0
# 17           1.0             0        0.0            0.0         0.0
# ...          ...           ...        ...            ...         ...
# 2904         0.0             2        9.0           48.0         9.0
# 2905         0.0             2        8.0          125.0         8.0
# 2906         0.0             2        8.0          199.0         8.0
# 2915         1.0             2       27.0            0.0        37.0
# 2929         1.0             2       12.0           48.0        13.0
#
#       Lot.Area  Full.Bath  BsmtFin.SF.1  Garage.Cars  X1st.Flr.SF  Exter.Qual  \
# ...

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1155 entries, 0 to 2929
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Fireplaces     1155 non-null   float64
#  1   Kitchen.Qual   1155 non-null   int64
#  2   Remod.Age      1155 non-null   float64
#  3   Open.Porch.SF  1155 non-null   float64
#  4   Garage.Age     1155 non-null   float64
#  5   Lot.Area       1155 non-null   float64
#  6   Full.Bath      1155 non-null   float64
#  7   BsmtFin.SF.1   1155 non-null   float64
#  8   Garage.Cars    1155 non-null   float64
#  9   X1st.Flr.SF    1155 non-null   float64
#  10  Exter.Qual     1155 non-null   int64
#  11  Total.Bsmt.SF  1155 non-null   float64
#  12  Garage.Area    1155 non-null   float64
#  13  Gr.Liv.Area    1155 non-null   float64
#  14  Overall.Qual   1155 non-null   int64
#  15  SalePrice      1155 non-null   float64
# dtypes: float64(13), int64(3)
# memory usage: 153.4 KB
